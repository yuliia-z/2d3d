# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d.art3d import Path3DCollection

# %%
points = np.array([
    [-1, -1.5, 1],
    [0, 1.5, -2],
    [-1, -1.5, -2],
    [-2, 1.5, 1],
    [-2, 1.5, -2],
    [0, 1.5, 1]
])

verts = [
    (points[3], points[0]),
    (points[0], points[5]),
    (points[0], points[2]),
    (points[5], points[3]),
    (points[5], points[1]),
    (points[2], points[1])
]

verts_dashes = [
    (points[2], v[4]),
    (points[3], v[4]),
    (points[4], v[1])
]

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(v[:, 0], v[:, 1], v[:, 2])

ax.set_xlim(-2,2)
ax.set_ylim(-2,2)
ax.set_zlim(-2,2)

poly = Poly3DCollection(verts, facecolors=(0., 0., 0., 0.), linewidths=2, edgecolors='black', linestyle="-")
poly_dashes = Poly3DCollection(verts_dashes, facecolors=(0., 0., 0., 0.), linewidths=2.5, edgecolors='black', linestyle=":")

ax.add_collection3d(poly)
ax.add_collection3d(poly_dashes)

ax.view_init(azim=-40, elev=20)
plt.show()
